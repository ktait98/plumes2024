# %%
import pandas as pd
pd.options.display.max_rows = 5000

# %%
df = pd.read_csv('dry_adv1.csv')

# %%
df.iloc[0:5000].head(5000)
# Out:
#      Unnamed: 0              age  waypoint  air_pressure  latitude    v_wind  \
# 0             0  0 days 00:10:00         0           NaN  0.027911       NaN
# 1             1  0 days 00:10:00         1           NaN  0.407291       NaN
# 2             2  0 days 00:20:00         0           NaN  0.030613       NaN
# 3             3  0 days 00:10:00         2           NaN  0.789500       NaN
# 4             4  0 days 00:20:00         1           NaN  0.408300       NaN
# 5             5  0 days 00:30:00         0           NaN  0.033546       NaN
# 6             6  0 days 00:10:00         3           NaN  1.175146       NaN
# 7             7  0 days 00:20:00         2           NaN  0.791241       NaN
# 8             8  0 days 00:30:00         1           NaN  0.409525       NaN
# 9             9  0 days 00:40:00         0           NaN  0.036668       NaN
# 10           10  0 days 00:10:00         4           NaN  1.560732       NaN
# ...
